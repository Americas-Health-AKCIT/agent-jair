# %%
import pandas as pd

df_requisicao = pd.read_csv('data/Evah/OMNI_DADOS_REQUISICAO.csv', encoding='latin1')
# Out:
# C:\Users\JoaoC\AppData\Local\Temp\ipykernel_39900\853523274.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_requisicao = pd.read_csv('data/Evah/OMNI_DADOS_REQUISICAO.csv', encoding='latin1')

# %%
df_requisicao.describe(include='all')
# Out:
#         ID_REQUISICAO DT_ATUALIZACAO  ID_BENEFICIARIO  ID_PRESTADOR  \
# count    1.132997e+06        1132997     1.132997e+06  1.132938e+06
# unique            NaN            504              NaN           NaN
# top               NaN       11/09/23              NaN           NaN
# freq              NaN           6397              NaN           NaN
# mean     4.157825e+07            NaN     1.348259e+05  1.297902e+03
# std      5.957691e+05            NaN     7.276045e+04  9.091231e+02
# min      1.877580e+05            NaN     2.000000e+01  1.000000e+00
# 25%      4.129660e+07            NaN     7.478500e+04  4.110000e+02
# 50%      4.159092e+07            NaN     1.382520e+05  1.224000e+03
# 75%      4.188519e+07            NaN     1.976830e+05  1.925000e+03
# max      4.218016e+07            NaN     2.577670e+05  3.580000e+03
#
#         ID_PROFISSIONAL DS_STATUS_REQUISICAO DT_REQUISICAO DT_FIM_ANALISE  \
# count      1.132954e+06              1132997       1132997        1132671
# ...
